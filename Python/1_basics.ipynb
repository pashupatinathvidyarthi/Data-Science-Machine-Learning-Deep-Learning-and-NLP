# %%
## Basics Syntax Rule in Python
## Case sensitivity >> Python is case-sensitive.


name="Pashupati"
Name="Nath"

print(name)
print(Name)
# Out:
# Pashupati
# Nath

# %%
##This is single line comments

'''
This is a example of multi-line comments.
'''
# Out:
# '\nThis is a example of multi-line comments.\n'
