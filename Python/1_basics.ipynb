# %%
## Basics Syntax Rule in Python
## Case sensitivity

# %%
##This is singlee line comments

'''
This is a example of multi-line comments.
'''
# Out:
# '\nThis is a example of multi-line comments.\n'
