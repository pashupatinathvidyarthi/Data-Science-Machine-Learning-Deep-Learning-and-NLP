# %% [markdown]
# # Introduction to Dictionaries
#
# Dictionaries are unordered collections of items. They store data in key-value pairs. Keys must be unique and immutable (e.g., strings, numbers, or tuples), while values can be of any types.

# %%
## Creating dictionaries
empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
print(empty_dict)
# Out:
# {}

# %%
student={"name":"Pashupati","age":22,"grade":24}
print(student)
print(type(student))
# Out:
# {'name': 'Pashupati', 'age': 22, 'grade': 24}
# <class 'dict'>

# %%
## Error

student={"name":"Pashupati","age":22,"name":24}  ##Do not hold duplication key pair value
print(student)
# Out:
# {'name': 24, 'age': 22}

# %%
## Accessing Dictionary Elements

student={"name":"Pashupati","age":22,"grade":'A'}
print(student)
# Out:
# {'name': 'Pashupati', 'age': 22, 'grade': 'A'}

# %%
## Accessing Dictionary Elements
print(student['grade'])
print(student['age'])

## Accessing using get() method
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name',"Not Availabel"))
# Out:
# A
# 22
# A
# None
# Not Availabel

# %%
## Modifying Dictionary Elements
## Dictionay are mutable, so you can add, update or delete elements
print(student)
# Out:
# {'name': 'Pashupati', 'age': 22, 'grade': 'A'}

# %%
##Updating Value of a particular key
student["age"]=23
print(student)
# Out:
# {'name': 'Pashupati', 'age': 23, 'grade': 'A'}

# %%
##Adding new Key Value Pair in dictionary
student["address"]="India"
print(student)
# Out:
# {'name': 'Pashupati', 'age': 23, 'grade': 'A', 'address': 'India'}

# %%
## Deleting a Key Value Pair
print(student)
del student['age']
print(student)
# Out:
# {'name': 'Pashupati', 'age': 23, 'address': 'India'}
# {'name': 'Pashupati', 'address': 'India'}

# %%
## Dictionary Methods

keys=student.keys() ##To get all the keys
print(keys)
value=student.values() ##To get all the values
print(value)

items=student.items() ##To get all key value pair in the form of list of tuple
print(items)
# Out:
# dict_keys(['name', 'address'])
# dict_values(['Pashupati', 'India'])
# dict_items([('name', 'Pashupati'), ('address', 'India')])

# %%
##Shallow Copy

student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Pashupati', 'address': 'India'}
# {'name': 'Pashupati', 'address': 'India'}

# %%
student["name"]="Nath"
print(student)
print(student_copy)
# Out:
# {'name': 'Nath', 'address': 'India'}
# {'name': 'Nath', 'address': 'India'}
