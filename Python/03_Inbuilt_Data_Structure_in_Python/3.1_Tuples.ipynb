# %% [markdown]
# # Introduction to Tuples
#
# ##### Explanation:
# Tuples are ordered collections of items that are immutable. They are similar to lists, but their immutability makes them different

# %%
## Creating a tuple

empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
tpl=tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple=(1,"Hello World",3.14,True)
print(mixed_tuple)
# Out:
# (1, 'Hello World', 3.14, True)

# %%
## Accessing Tuple Elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[0])
print(numbers[2])
print(numbers[-1])
# Out:
# 1
# 3
# 6

# %%
numbers[0:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers[::]
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
## Tuples Operations

print(numbers)
print(mixed_tuple)

concatenation_tuple=numbers+mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 6)
# (1, 'Hello World', 3.14, True)
# (1, 2, 3, 4, 5, 6, 1, 'Hello World', 3.14, True)

# %%
mixed_tuple *3
# Out:
# (1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True)

# %%
numbers*3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## Immutable Nature of Tuple
#Tuples are immutable, meaning their elements cannot be changed once assigned.

lst=[1,2,3,4,5]
print(lst)

lst[1]="Pashupati"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Pashupati', 3, 4, 5]

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers[1]="Pashupati"  ##Through an error as tuple is immutable

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
## tuple MEthods

print(numbers.count(1))
print(numbers.index(3))  ##Return first index of value.
# Out:
# 1
# 2

# %%
## Packing and Unpacking Tuple

#packing
packed_tuple=1,"Hello",3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
##Unpacking
a,b,c=packed_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
## Unpacking with *

numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## Nested Tuples

##Nested List
lst=[[1,2,3,4],[6,7,8,9],[1,"Hello",3.14,"c"]]
print(lst[0])

print(lst[0][2])
# Out:
# [1, 2, 3, 4]
# 3

# %%
print(lst[0][0:3])
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"Hello",3.14,"c")]
print(lst[2][0:3])
# Out:
# (1, 'Hello', 3.14)

# %%
nested_tuple=((1,2,3),("a","b","c"),(True,False))


##Access the element inside the tuple
print(nested_tuple[0])

print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
## Iterating over nested tuple

for sub_tuple in nested_tuple:
    for iteam in sub_tuple:
        print(iteam,end="")
    print()
# Out:
# 123
# abc
# TrueFalse
