# %% [markdown]
# ## Decorators
#
# Decorators are a powerful and flexible feature in Python that allows you to modify the behaviour of a function or class method. They are commonly used to add functionality to functiions or methods without modifying their actual code. This lesson covers the basics of decorators, including how to create and use them.

# %%
## function copy
## closures
## decorators

# %%
## function copy
def welcome():
    return "Welcome to the Advance Python Course"

welcome()
# Out:
# 'Welcome to the Advance Python Course'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to the Advance Python Course
# Welcome to the Advance Python Course

# %%
## Closure i.e finction inside a function
# Out:
# 'Welcome to the Advance Python Course'
