# %%
## if statement

age=20

if age>=18:
    print("You are allow to vote in the elections")
# Out:
# You are allow to vote in the elections

# %%
age>=18
# Out:
# True

# %%
## Else >> The else statement executes a block of code if the condition in the if statement is false

age=16
if age>=18:
    print("You are eligible for voting")
else:
    print("Your are a minor")
# Out:
# Your are a minor

# %%
## elif 
## The elif statement allows you to check multiple conditions. It stands for 'else if'ArithmeticError

age=17

if age<13:
    print("You are a child.")
elif age<18:
    print("You are a teenager")
else:
    print("You are adult")
# Out:
# You are a teenager

# %%
## Nested Conditional Statements 

## You can place one or more if, elif, or else statements inside another if, elif, or else statement to create nesteed conditional statements.

##number even,odd,negative

num=int(input("Enter a number : "))
if num>0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is negative")
# Out:
# The number is positive
# The number is even

# %%
## Practical Examples

## da=etermine if a year is a leap year using nested condition statement

year=int(input("Enter a year : "))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year," is a leap year")
        else:
            print(year,"Not a leap year")
    else:
        print(year," is a leap year")
else:
    print(year," is not a leap year")
# Out:
# 2022  is not a leap year

# %%
num1=float(input("Enter first number : "))
num2=float(input("Enter second number : "))
operation=input("Enter operation (+, -, *, /,) : ")

#Perform the requested operation
if operation == '+':
    result=num1+num2
elif operation == '-':
    result=num1-num2
elif operation == '*':
    result=num1*num2
elif operation=='/':
    if num2 !=0:
        result=num1/num2
    else:
        result="Error! Division by Zero."
else:
    result="Invalid Operation"

print("Result : ",result)
# Out:
# Result :  36.0

# %%
## Determine the ticket price based on age and wheather the person is a student.
# Ticket pricing based on age and student status


#Take user input
age=int(input("Enter your age : "))
is_student=input("Are you a student ? (YES/NO) : ").upper() ## .upper() Return a copy of the string converted to uppercase.


#Determine ticket price
if age < 5:
    price="Free"
elif age<=12:
    price="$10"
elif age <=17:
    if is_student=="YES":
        price="$12"
    else:
        price="$15"
elif age<=64:
    if is_student=="YES":
        price="$18"
    else:
        price="$25"
else:
    price="$20"

print("Price : ",price)
# Out:
# Price :  $18
