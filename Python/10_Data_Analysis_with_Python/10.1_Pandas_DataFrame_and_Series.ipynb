# %% [markdown]
# ## Pandas-DataFrame and Series
#
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures. Series and DataFrame. A Series is a one-dimensional array-like object, while DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
## Series
## A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd
data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n",series)
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
## Create a series from dictionary 
data={'a':1,'b':2,'c':3,'d':4}
series=pd.Series(data)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
## To give specific index
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
##DataFrame
## create a dataframe from a dictionary of lisst

data={
    "Name":['Pashupati','Vantika','Abhishek'],
    "Age":[23,5,25],
    "City":["Bikramganj","Arrah","Bikramganj"]
}

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#         Name  Age        City
# 0  Pashupati   23  Bikramganj
# 1    Vantika    5       Arrah
# 2   Abhishek   25  Bikramganj
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
np.array(df)
# Out:
# array([['Pashupati', 23, 'Bikramganj'],
#        ['Vantika', 5, 'Arrah'],
#        ['Abhishek', 25, 'Bikramganj']], dtype=object)

# %%
result=0.3+0.6
print(result)
# Out:
# 0.8999999999999999

# %%
#Create a dataframe from a list of dictionary

data=[
    {"Name":'Pashupati','Age':22,'City':"Bikramganj"},
    {"Name":'Abhishek','Age':24,'City':"Bikramganj"},
    {"Name":'Vantika','Age':5,'City':"Arrah"},
]
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#         Name  Age        City
# 0  Pashupati   22  Bikramganj
# 1   Abhishek   24  Bikramganj
# 2    Vantika    5       Arrah
# <class 'pandas.core.frame.DataFrame'>

# %%
pd.read_csv('online_sales_data_1000.csv')
# Out:
#      Transaction ID        Date         Category            Product  Quantity  \
# 0             10001  2025-10-06           Sports           Yoga Mat         3
# 1             10002  2026-01-19            Books      Atomic Habits         1
# 2             10003  2025-05-22         Clothing             Jacket         2
# 3             10004  2025-04-09  Beauty Products           Lipstick         2
# 4             10005  2026-02-21         Clothing             Jacket         2
# ..              ...         ...              ...                ...       ...
# 995           10996  2025-11-06      Electronics        MacBook Air         4
# 996           10997  2025-05-05           Sports      Tennis Racket         1
# 997           10998  2026-03-27  Beauty Products          Face Wash         5
# 998           10999  2025-06-23            Books  Rich Dad Poor Dad         4
# 999           11000  2026-03-31            Books      The Alchemist         2
#
# ...
