# %% [markdown]
# #### Introduction to Streamlit
#
# Streamlit is an open-source app framework for Machine Learning and Data Science Projects. It allows you to create a beautiful web applications for your machine learning and data science projects with simple python scripts.

# %%
pip install streamlit
# Out:
# ...
#      ---------------------------------------- 9.1/9.1 MB 6.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 795.4/795.4 kB 8.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 208.6/208.6 kB 6.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 11.3/11.3 MB 7.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.0/7.0 MB 5.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.9/6.9 MB 6.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 437.1/437.1 kB 5.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 27.5/27.5 MB 5.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 64.7/64.7 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 79.1/79.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 90.6/90.6 kB 5.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 444.9/444.9 kB 4.6 MB/s eta 0:00:00
# ...
