# %%
import os

# %%
## Creating a new directory
new_directory="package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}'create")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 ## Creating a new directory
#       2 new_directory="package"
# ----> 3 os.mkdir(new_directory)
#       4 print(f"Directory '{new_directory}'create")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'package'

# %%
## Listing Files and Directories

items=os.listdir('.')
print(items)
# Out:
# ['6.0_File_Operation.ipynb', '6.1_File_Path.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'package']

# %%
## Joining Paths

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\pashu\Downloads\Data-Science-Machine-Learning-Deep-Learning-and-NLP\Python\06_File_Handling_in_Python\folder\file.txt

# %%
## Checking if a Path is a File or Directory exists 
path='example1.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' does not exists.")
# Out:
# The path 'example1.txt' does not exists.

# %%
## Another method to for Checking if a Path is a File or Directory exists

import os
path='example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory")
# Out:
# The path 'example.txt' is a file.

# %%
## getting the absolute path

relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\pashu\Downloads\Data-Science-Machine-Learning-Deep-Learning-and-NLP\Python\06_File_Handling_in_Python\example.txt
