# %%
## Basics Syntax Rule in Python
## Case sensitivity >> Python is case-sensitive.


name="Pashupati"
Name="Nath"

print(name)
print(Name)
# Out:
# Pashupati
# Nath

# %%
##This is single line comments

'''
This is a example of multi-line comments.
'''
# Out:
# '\nThis is a example of multi-line comments.\n'

# %%
##Indentation
## Python uses indentation to define block of code. Consistent use of spaces (commmonly 4) or a tab is required.

age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
## This is single line-comment
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation
## Use a backslash (\) to continue a statement to the next line.

total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple statement on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Understanding Semnatics in python
# Variable Assignment
age=32  #age is an integer
name="Pashuapti"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference >> During run time we can can type of variable
variable=10
print(type(variable))
variable="Pashupati"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
print(age) #Here we got indentation error
