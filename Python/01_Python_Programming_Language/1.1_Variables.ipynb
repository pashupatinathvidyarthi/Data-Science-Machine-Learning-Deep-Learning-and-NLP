# %%
a=100

# %%
## Declaring and assigning Variables

age=32
height=6.1
name="Pashupati"
is_Student=True

##printing the variables

print("age : ",age)
print("height :",height)
print("Name :",name)
# Out:
# age :  32
# height : 6.1
# Name : Pashupati

# %%
## Naming Conventions
## Variable name should be descriptive
## They must be start with a letter or '_' and contains letter,numbers and underscores
## Variable names case sensitive

#valis variables name

first_name="Pashupati"
last_name="Nath Vidyarthi"

# %%
## Inavlid Variable Name

#2gae=30
#first-name="Pashupati"
#@name="Pashupati"

# %%
## Case-senstivity

name="Pashupati"
Name="Nath"

# %%
name
# Out:
# 'Pashupati'

# %%
## Undderstanding Variable types
## Python is dynamically typed >> The type of variable are determined at run-time

age=25  #int
height=6.1 #float
name="Pashupati" #string
is_Student=True  #bool

print(type(name))
# Out:
# <class 'str'>

# %%
## type checking and conversion

type(height)
# Out:
# float

# %%
age=25
print(type(age))

## Type conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="Pashupati"
int(name) ##We can not convert string to an inter or float

# %%
height=5.11
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 5

# %%
float(int(height))
# Out:
# 5.0

# %%
## DDynamic Typing
## Python the the type of variable to change as the program executes
var=10
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input

age=int(input("What is your age : "))
print(age,type(age))
# Out:
# 22 <class 'int'>

# %%
## Simple Calculator

num1=float(input("Enter first number : "))
num2=float(input("Enter second number : "))

sum=num1+num2
difference=num1-num2
product=num1*num2
quotient=num1/num2

print("You entered ",num1, " and ",num2)
print("Sum : ",sum)
print("Difference : ",difference)
print("Product : ",product)
print("Quotient : ",quotient)
# Out:
# You entered  66.0  and  46.0
# Sum :  112.0
# Difference :  20.0
# Product :  3036.0
# Quotient :  1.434782608695652
