# %%
## Integers Example

age=35
type(age)
# Out:
# int

# %%
## Floating Point Datatype

width=5.11
print(width)
print(type(width))
# Out:
# 5.11
# <class 'float'>

# %%
## String Datatype

name="Pashupati"
print(name)
print(type(name))
# Out:
# Pashupati
# <class 'str'>

# %%
## Boolean Datatypes

type(True)
# Out:
# bool

# %%
is_True=True
print(type(is_True))
# Out:
# <class 'bool'>

# %%
bool()
# Out:
# False

# %%
a=10
b=10

type(a==b)
# Out:
# bool
