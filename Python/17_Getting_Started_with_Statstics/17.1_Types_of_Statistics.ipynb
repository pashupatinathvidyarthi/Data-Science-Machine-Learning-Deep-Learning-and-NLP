# %% [markdown]
# ## Types of Statistics
#
# 1. DESCRIPTIVE
# 2. INFERENTIAL

# %% [markdown]
# ## Descriptive
# It consists of organising and summarizing of data.
#
# 1. Measure of Central Tendency
#     - Mean
#     - Median
#     - Mode
#
# 2. Measure of Dispersion
#     - Variance
#     - Standard Deviation
