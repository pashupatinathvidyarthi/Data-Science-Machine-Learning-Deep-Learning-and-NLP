# %% [markdown]
# #### Classes and Objects
#
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modelling real-world scenarious using classes and objects. This lesson covers the basics of creating classes and objects, including instances variables and methods.

# %%
### A class is a blue print for creating objects. Atrributes, methods

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x000001D16A86DA50>
# <__main__.Car object at 0x000001D16A8BD550>

# %%
audi.windows=4
print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.doors=4
## print(tata.windows) through an error

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
### Instance Variable and Methods
class Dog:
    ## Constructor
    def __init__(self,name,age): ## We can any name in place of "self" but good practice is to use self
        self.name=name
        self.age=age

    ## Creating Objects
    dog1=Dog("Buddy",3)
    print(dog1)
    print(dog1.name)
    print(dog1.age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 ### Instance Variable and Methods
# ----> 2 class Dog:
#       3     ## Constructor
#       4     def __init__(self,name,age): ## We can any name in place of "self" but good practice is to use self
#       5         self.name=name
#
# Cell In[7], line 9, in Dog()
#       6     self.age=age
#       8 ## Creating Objects
# ----> 9 dog1=Dog("Buddy",3)
#      10 print(dog1)
#      11 print(dog1.name)
#
# NameError: name 'Dog' is not defined

# %%
## Define a class with instance methods
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog("Lucky",4)
dog2.bark()
# Out:
# Buddy says woof
# Lucky says woof

# %%
### Modelling a BANK ACCOUNT

##Define a class for bank account

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount  
        print(f"{amount} is deposited. New Balance is {self.balance}")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient Funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New Balance is {self.balance}")
    
    def get_balance(self):
        return self.balance
    
## Create an account
account=BankAccount("Krish",5000)
print(account.balance)
# Out:
# 5000

# %%
## Call instance methods
account.deposit(100)
# Out:
# 100 is deposited. New Balance is 5100

# %%
account.withdraw(300)
# Out:
# 300 is withdrawn. New Balance is 4800

# %%
print(account.get_balance())
# Out:
# 4800
