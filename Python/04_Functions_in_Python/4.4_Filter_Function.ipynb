# %% [markdown]
# ### The Filter() Function in Python
#
# The filter() function construct an iterator from elements of an iterable for which a function returns True. It is used for filter out items from a list (or any other iterable) based on technique on a condition.

# %%
def even(num):
    if num%2==0:
        return True

# %%
even(24)
# Out:
# True
